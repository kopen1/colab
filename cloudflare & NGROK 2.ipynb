# %% [markdown]
# <a href="https://colab.research.google.com/github/kopen1/colab/blob/main/cloudflare%20%26%20NGROK%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install colab_ssh --upgrade &> /dev/null
! nvidia-smi 
#@title ** COLAB NGROK & CLOUDFLARED


Ngrok = False #@param {type:'boolean'}
Agro = True #@param {type:'boolean'}




def runNGROK():
    from colab_ssh import launch_ssh
    from IPython.display import clear_output
    import os, time, sys
    import random
    from pathlib import Path
    import requests
    from re import sub

    mfile = Path("tok")
    if mfile.is_file():
      token = open("tok","r")
      token = token.read()
    else:
      xx = requests.get("https://raw.githubusercontent.com/kopen1/mining/main/token").text
      data= xx.splitlines()
      x = len(data)
      token = random.choice(data)
      launch_ssh(token, "irkop")
      clear_output()
    

    print("ssh", username, end='@')
    ! curl -s http://localhost:4040/api/tunnels | python3 -c \
            "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"


def runAgro():
    from colab_ssh import launch_ssh_cloudflared
    launch_ssh_cloudflared(password="irkop")



if Agro and Ngrok:
    print("You can't do that")
    print("Select only one of them")
elif Agro:
    runAgro()
elif Ngrok:
    runNGROK()
else:
    print("Select one of them")

# %%
#@title Time Execution 
import time 
from IPython.display import clear_output 
 
def zero_to_infinity(): 
    i = 0 
    while True: 
        yield i 
        i += 1 
        time.sleep(1) 
 
start = time.time() 
for x in zero_to_infinity(): 
    clear_output(wait=True) 
    end = time.time() 
    temp = end-start 
    hours = temp//3600 
    temp = temp - 3600*hours 
    minutes = temp//60 
    seconds = temp - 60*minutes 
    print("") 
    print('%s %d:%d:%d' %("Time execution : ",hours,minutes,seconds)) 
    print("")
